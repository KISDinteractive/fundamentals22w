# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
covidData=pd.read_csv('Nowcast_R_aktuell.csv')
covidData
# Out:
#           Datum  PS_COVID_Faelle  UG_PI_COVID_Faelle  OG_PI_COVID_Faelle  \
# 0    2020-03-02              303                 292                 318
# 1    2020-03-03              321                 304                 336
# 2    2020-03-04              449                 430                 469
# 3    2020-03-05              503                 483                 524
# 4    2020-03-06              757                 735                 782
# ..          ...              ...                 ...                 ...
# 962  2022-10-20            52689               48847               57049
# 963  2022-10-21            51751               46754               58822
# 964  2022-10-22            52260               44500               60244
# 965  2022-10-23            63700               46412               80222
# 966  2022-10-24            75519               55870               98082
#
#      PS_COVID_Faelle_ma4  UG_PI_COVID_Faelle_ma4  OG_PI_COVID_Faelle_ma4  \
# ...

# %%
xValues = range(len(covidData['Datum']))
yValues = covidData['PS_COVID_Faelle']
plt.plot(xValues, yValues)
plt.show()
